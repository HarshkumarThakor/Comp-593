# %% [markdown]
# <a href="https://colab.research.google.com/github/HarshkumarThakor/Comp-593/blob/main/WEEK_4_ADVANCED_SQL_AND_FILES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 4 - Advanced SQL / Writing Files
#
# In this week's lab, we are going to expand our Really Simple Social Network by adding another table that will record connections between people! Because after all, what good is a social network if you can't ... be social?
#
# Afterwards, we will be in a good position to run a report on the data, and then we can sell it to marketers for a massive profit! Isn't it great how few people read the terms of service? `/s`

# %% [markdown]
# ## Importing our database
# Since we are using a new colab notebook, we will need to reimport our database. Check your D2L Submission if you didn't keep a copy, you should be able to redownload it there. Run the below code block and the file upload picker will appear, after uploading your Database file, check that it appears in the `Files` tab of colab.
#
# Remember that you may need to update the listings before it will appear.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-93888a4b-b49a-4ecb-8a0c-d8c375139681" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-93888a4b-b49a-4ecb-8a0c-d8c375139681">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving social_network.db to social_network (1).db

# %% [markdown]
# ## Creating our relationship table
#
# In the code block below, we will be creating a new table in our database for `relationships` with the following parameters:
#
#
# 1.   A primary key column called `id` with the `INTEGER` datatype that is `NOT NULL`
# 2.   A foreign key column called `user_id` that links to the `id` column of the `people` table with the `INTEGER` datatype that is `NOT NULL`
# 3.   Another foreign key column called `friend_id` that also links to the `id` column of the `people` table with the `INTEGER` datatype that is `NOT NULL`
# 4.   A `date_created` table with the `DATE` datatype that is `NOT NULL`
#
# The Below codeblock will get you started:

# %%
import sqlite3

#Retreive the Connection object, rename the file to match your uploaded DB if necessary.
myConnection = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

#The Primary Key column has been provided for you,
#Replace '#!...' with the remaining column names, datatypes, and foreign key declarations.
#Use the Lecture notes and the previous lab if you are unsure.
createRelationshipsTable = """CREATE TABLE IF NOT EXISTS relationships (
                          id integer PRIMARY KEY NOT NULL,
                          user_id integer NOT NULL,
                          friend_id integer NOT NULL,
                          FOREIGN KEY  (user_id) REFERENCES people (id),
                          FOREIGN KEY (friend_id) REFERENCES people (id)
                        );"""

#Once again, we will execute the query, persist the changes, and close our connection.
myCursor.execute(createRelationshipsTable)
myConnection.commit()
myConnection.close()

# %%
myConnection = sqlite3.connect('social_network.db')
myCursor = myConnection.cursor()

myCursor.execute("SELECT group_concat(name,',') FROM pragma_table_info('relationships')")
print(myCursor.fetchone())

myConnection.close()
# Out:
# ('id,user_id,friend_id',)

# %% [markdown]
# ## Populating Relationship Data
#
# We're not going to be picky about who knows who - so for the purposes of this lab, we're going to use our own version of an AI matchmaker, the `randrange()` method.
#
# Complete the below codeblock, inserting 1000 new rows into the relationships table.
# Use a random number between `1 - 1000` for the `user_id` and `friend_id` columns. This will link up to the `id` column of the `people` table and effectivly simulate a random network of relationships.
#
# The below code block is purposely sparse, as you should be able to use the patterns you've identified in the previous lab to complete this task.

# %%
from math import frexp
import sqlite3
from datetime import datetime #For generating dates and times
from random import randrange #For generating random numbers within a range

#Retreive the Connection object, rename the file to match your uploaded DB if necessary.
myConnection = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

#Complete the below query
addRelationshipQuery = """INSERT INTO relationships (user_id, friend_id)
                          VALUES (?, ?);"""

for _ in range(1000):
  user_id = randrange(1, 1001)
  
  friend_id = user_id
  while friend_id == user_id:
    friend_id = randrange(1, 1001)
  
  #Populate the arguments that will be used in the query
  args = (user_id, friend_id)
  
  #Execute the query
  myCursor.execute(addRelationshipQuery, args)

#Commit your changes and close the connection.
myConnection.commit()
myConnection.close()

# %%
import sqlite3
from pprint import pprint

myConnection = sqlite3.connect('social_network.db')
#
# If this was explained in awkward pseudo code, it might go something like this:
# ```
# SELECT all relationships
# JOIN them to the people they belong to
# GROUP the results by the person's ID
# return the person's name and COUNT of their relationships
# ```
#
# After you have collected the data, you will need to write it to a `.txt` file.
#
# **Your submission will include the report `.txt` file, the copy of your updated `social_network.db` file, and a link to the colab notebook.**
#
# Look at the aggregate functions from Week 3 and the Join examples from Week 4. There are a few different ways that you can structure a query to reach the correct answer.
#
# **At a minimum, you will need to use a `LEFT JOIN` statement, a `GROUP BY` statement, and a `COUNT()` aggregate function.**
#
# The below code block will get you started:

# %%
import sqlite3
from pprint import pprint

#Retreive the Connection object, rename the file to match your uploaded DB if necessary.
myConnection = sqlite3.connect('social_network.db')
myCursor = myConnection.cursor()

#Complete the below query
query =  """SELECT people.name, relationships.friend_id FROM relationships
            LEFT JOIN people ON relationships.user_id = people.id
         """

myCursor.execute(query)
results = myCursor.fetchall()
pprint(results)

myConnection.close()

#Uncomment the below line after you have determined what the correct mode will be for your file pointer.
#fp = open('report.txt', mode='')


#for result in results:
  #You will want to write the results to the file pointer here.
  #Use the newline character \n to create a line break in each write() statement.
  #Use print() statements as sanity checks if you are unsure of the integrity of your data.

#Don't forget to close the file pointer after you have finished!
# Out:
# [('Jennifer Simpson', 189),
#  ('Mary Valentine', 835),
#  ('Tracy Hardy', 763),
#  ('Matthew Hopkins', 159),
#  ('Shawn Rose', 848),
#  ('Amy Walker', 658),
#  ('Alexander Wood', 351),
#  ('Andrea Fernandez', 518),
#  ('Mary Campbell', 152),
#  ('Jordan West', 964),
#  ('Suzanne Sampson', 758),
#  ('Kara Ramirez', 472),
#  ('Nancy Ortiz', 204),
#  ('Robert Miller', 699),
#  ('Steven Robinson', 556),
#  ('Nicole Gonzales', 858),
#  ('Vicki Jensen', 596),
#  ('Alyssa Holmes', 127),
#  ('Jennifer Perry', 894),
#  ('Troy Bell', 605),
#  ('John King', 4),
#  ('Stephanie Harris', 381),
#  ('Bradley Martinez', 933),
#  ('Cindy Roberson', 3),
#  ('Mrs. Brittany Wade DVM', 528),
#  ('Stacy Finley', 408),
#  ('Stacey Patton', 232),
#  ('Kristen Marshall', 98),
#  ('Holly Harris', 467),
#  ('Angela Shah', 75),
#  ('Adam Williams', 435),
#  ('Tara Harrison', 255),
#  ('Eric Johnson', 308),
#  ('Walter Roberts', 388),
#  ('Mallory Howard', 162),
#  ('Kaitlyn Greene', 297),
#  ('Patrick Norris', 142),
#  ('Matthew Kent', 401),
#  ('Mary Schneider', 968),
#  ('Wanda Johnson', 220),
#  ('Caitlin Ewing', 472),
#  ('Natalie Adams', 804),
#  ('William Dawson', 367),
#  ('Hannah Norris', 370),
#  ('David Kelly', 669),
#  ('Richard Davies', 486),
#  ('Tyler Yang', 279),
#  ('Joseph Espinoza', 614),
#  ('Julie Woodard', 53),
#  ('Gary Smith', 587),
#  ('Rebecca Alvarez', 319),
#  ('Julia Craig', 258),
#  ('Matthew Rios', 316),
#  ('Lisa Richard', 586),
#  ('April Robinson DDS', 18),
#  ('Shannon Daniel', 122),
#  ('Mike Richardson', 959),
#  ('Elizabeth Park', 131),
#  ('Jason Joseph', 263),
#  ('Dean Davis', 774),
#  ('Dakota Morrison', 551),
#  ('Autumn Horton', 346),
#  ('Alexander Wood', 385),
#  ('Sean George', 816),
#  ('Crystal Delgado', 344),
#  ('Alexandra Hood', 275),
#  ('Mary Roman', 300),
#  ('Dr. Megan Walker', 943),
#  ('Paul Martin', 610),
#  ('Chad Rodriguez', 319),
#  ('Juan Bailey', 480),
#  ('Joshua Baker', 582),
#  ('Sarah Le', 618),
#  ('Deanna Brooks', 103),
#  ('Ronald Henderson', 538),
#  ('Vicki Jensen', 314),
#  ('Janet Dean', 390),
#  ('Jill Jordan', 427),
#  ('Angela Booth', 458),
#  ('Jesse Black', 349),
#  ('Hannah Cochran', 473),
#  ('Sabrina Cruz', 540),
#  ('Douglas Barton', 69),
#  ('Mary Schneider', 11),
#  ('Kim Johnson', 577),
#  ('Jodi Reynolds', 165),
#  ('Nathan Smith', 397),
#  ('Hannah Brown', 925),
#  ('Dr. Jose Friedman', 168),
#  ('Robert Duncan', 371),
#  ('Warren Sanders', 154),
#  ('Lisa Zimmerman', 937),
#  ('Justin Patterson', 505),
#  ('Alice Travis', 784),
#  ('Christine Young', 593),
#  ('Angela Martin', 546),
#  ('Justin Gaines', 677),
#  ('Reginald Payne', 774),
#  ('Sarah Rodriguez', 460),
#  ('William Hardy', 496),
#  ('Christopher Murphy', 941),
#  ('Rebecca Weaver', 56),
#  ('Danielle Hickman', 5),
#  ('Linda Wilcox', 592),
#  ('Julia Craig', 595),
#  ('Danielle Perry', 69),
#  ('Evan Salas', 284),
#  ('Angela Martin', 816),
#  ('Robert Duncan', 15),
#  ('Jerry Nicholson', 121),
#  ('April Walker', 524),
#  ('Michael Lang', 545),
#  ('Julie Henderson', 870),
#  ('Lori Martinez', 381),
#  ('Emily Davis', 130),
#  ('Deanna Herman', 321),
#  ('Patricia Fisher', 658),
#  ('Dylan Crawford', 383),
#  ('Tina Park', 772),
#  ('Jason Johnson', 48),
#  ('Mary Perry', 146),
#  ('Melanie Reyes', 798),
#  ('Tyler Murphy', 987),
#  ('Hannah Norris', 829),
#  ('Jennifer Hogan', 454),
#  ('Michelle Hall', 20),
#  ('Alexis Ward', 493),
#  ('Juan Bailey', 24),
#  ('Timothy Kelly', 955),
#  ('Jeffrey Morrow', 732),
#  ('Bradley Martinez', 755),
#  ('Javier Perez', 759),
#  ('Mary Schneider', 925),
#  ('Natalie Adams', 854),
#  ('Ryan Clark', 914),
#  ('Justin Patterson', 667),
#  ('Robert Blevins', 521),
#  ('Rhonda Morris', 413),
#  ('Tanya Wilcox', 152),
#  ('Scott Mccarty', 59),
#  ('Heather Hernandez', 98),
#  ('David Ross', 723),
#  ('Dana Carpenter', 83),
#  ('David Hull', 765),
#  ('David Kemp', 554),
#  ('Zachary Luna', 70),
#  ('Angela Smith', 272),
#  ('Jason Adams', 673),
#  ('Natalie Zuniga', 416),
#  ('Emily Davis', 970),
#  ('Jerry Green', 579),
#  ('Valerie Mcmahon', 581),
#  ('Gary Smith', 35),
#  ('Julie Henderson', 239),
#  ('Shawn Rose', 860),
#  ('Jonathan Berry', 487),
#  ('Sherri Nguyen', 314),
#  ('Christopher Murphy', 724),
#  ('Kristina Watts', 669),
#  ('Brenda Joseph', 1),
#  ('Jessica Phillips', 497),
#  ('Heather Hernandez', 70),
#  ('Olivia Keith', 849),
#  ('Lindsay Reed', 173),
#  ('Rebecca Martinez', 881),
#  ('John King', 165),
#  ('Jack Pratt', 138),
#  ('Heather Robinson', 974),
#  ('Tina Park', 438),
#  ('Ian Daniels', 951),
#  ('Lucas Alexander', 854),
#  ('Ryan Porter', 693),
#  ('Manuel Rodriguez', 55),
#  ('April Mcguire', 983),
#  ('Daniel Scott', 483),
#  ('Madison Harrison', 312),
#  ('David Scott', 86),
#  ('Karen Ingram', 409),
#  ('Andrew Snyder', 362),
#  ('Lisa Cox', 196),
#  ('Ashley Petersen', 861),
#  ('Erin Rodriguez', 732),
#  ('Russell Howard', 737),
#  ('Jamie Martinez', 577),
#  ('Bruce Porter', 918),
#  ('Karen Ingram', 424),
#  ('David Howell', 299),
#  ('Jordan Simon', 581),
#  ('Brandon Edwards', 359),
#  ('Deborah Armstrong', 669),
#  ('Rebecca Martinez', 695),
#  ('Paula Vance', 22),
#  ('Kathryn Miller', 951),
#  ('Joseph Carr', 985),
#  ('Jacob Deleon', 948),
#  ('Andrea Fernandez', 597),
#  ('Anthony Flores', 963),
#  ('Phillip Diaz', 214),
#  ('Jamie English', 153),
#  ('Sabrina Cruz', 105),
#  ('Kylie Molina', 888),
#  ('Jose Davis', 141),
#  ('Joseph Nelson', 767),
#  ('Leonard Bishop', 688),
#  ('Misty Brown', 12),
#  ('Andrew Brown', 998),
#  ('Melinda Cox', 77),
#  ('Kristi Banks', 599),
#  ('Lisa Tyler', 181),
#  ('Amy Walker', 347),
#  ('Eric Walls', 137),
#  ('Mario Jones', 130),
#  ('Tom Flores', 331),
#  ('Mary Lewis', 320),
#  ('Nicole Gonzales', 928),
#  ('Laurie Boyd', 726),
#  ('Brian Charles', 382),
#  ('Stephen Hill', 695),
#  ('Richard Martinez', 288),
#  ('Dorothy Morrison', 292),
#  ('Christopher Byrd', 306),
#  ('Chad Padilla', 321),
#  ('Tom Flores', 980),
#  ('Tracy Richardson', 578),
#  ('Jennifer Perry', 241),
#  ('Courtney Norris', 71),
#  ('Mr. Ryan Thompson', 255),
#  ('Angela Martin', 336),
#  ('Zachary Luna', 273),
#  ('Paul Gamble', 962),
#  ('Mrs. Anita Delgado', 967),
#  ('Krista Richards DDS', 181),
#  ('Sandra Cunningham', 366),
#  ('Jill Barnes', 967),
#  ('Christopher Garcia', 462),
#  ('Julian Case', 916),
#  ('Nicole Acevedo', 254),
#  ('Tom Flores', 433),
#  ('Angela Martin', 562),
#  ('Chad Lee', 425),
#  ('Vanessa Johnson', 632),
#  ('Bob Taylor', 223),
#  ('Jeffery Brown', 563),
#  ('Amanda Parks', 218),
#  ('Sara Zamora', 295),
#  ('Paul Smith', 439),
#  ('Joseph Lopez', 79),
#  ('Joe Morales', 226),
#  ('Joel Anthony II', 105),
#  ('Julie Ryan', 218),
#  ('Terrance Thomas', 179),
#  ('Richard Park', 531),
#  ('Jennifer Fuller', 269),
#  ('Lindsay Dominguez', 953),
#  ('Lynn Bush', 732),
#  ('David Heath', 175),
#  ('Joshua Frye', 939),
#  ('Margaret Gomez', 859),
#  ('Walter Roberts', 209),
#  ('Curtis Love', 243),
#  ('Mary Schneider', 169),
#  ('Emily Boyer', 814),
#  ('Timothy Blackburn', 224),
#  ('Jessica Nguyen', 165),
#  ('Kevin Russell', 136),
#  ('Amber Moore', 551),
#  ('April Bryan', 812),
#  ('Katherine Li', 832),
#  ('Jeffery Matthews', 583),
#  ('Wanda Johnson', 547),
#  ('Dorothy Morrison', 453),
#  ('Tiffany Weaver', 438),
#  ('Matthew Patel', 685),
#  ('Cassandra Sandoval', 100),
#  ('Christopher Chambers', 707),
#  ('Rebecca Weaver', 447),
#  ('Jenna Mccarthy', 930),
#  ('Sandra Johnson', 61),
#  ('Philip Barnett', 862),
#  ('Patrick Clayton III', 716),
#  ('Victor Boone', 554),
#  ('Shawn Simon', 111),
#  ('Cory Reyes', 795),
#  ('Matthew Patel', 293),
#  ('Thomas Lynn', 87),
#  ('Heather Carlson', 592),
#  ('Ian Daniels', 437),
#  ('Nicholas Reed', 627),
#  ('Keith Harper', 329),
#  ('Olivia Vasquez', 760),
#  ('Stephanie West', 596),
#  ('Christopher Chambers', 265),
#  ('Paula Schneider', 782),
#  ('Alicia Walsh', 862),
#  ('Kara Ramirez', 499),
#  ('Lisa Richard', 716),
#  ('Jacob Obrien', 608),
#  ('Jennifer Hogan', 929),
#  ('Jon Johnson', 707),
#  ('Douglas Holt', 598),
#  ('Julie Lewis', 372),
#  ('Anthony White', 377),
#  ('Brian Juarez', 58),
#  ('Cassie Reid', 148),
#  ('Rachel Williams', 347),
#  ('Mr. Steven Rogers MD', 183),
#  ('Anna Nguyen', 901),
#  ('Lisa Decker', 432),
#  ('Patrick Clayton III', 705),
#  ('Melissa Sanders', 52),
#  ('Alejandro Brown', 817),
#  ('Lisa Zimmerman', 298),
#  ('Mr. Ryan Thompson', 153),
#  ('Kathy Holmes', 440),
#  ('Richard Park', 109),
#  ('Amy Rhodes', 803),
#  ('Crystal Guerrero', 476),
#  ('Thomas Carroll', 403),
#  ('Jennifer Fuller', 967),
#  ('Elizabeth Sanchez', 226),
#  ('Nicholas Anderson', 413),
#  ('Steven Robinson', 138),
#  ('Hannah Norris', 387),
#  ('Eric Walls', 472),
#  ('Cindy Lambert', 404),
#  ('Paul Gamble', 251),
#  ('Mrs. Jenny Lewis', 71),
#  ('Dennis David Jr.', 597),
#  ('Christopher Cole', 1),
#  ('Eric Walls', 177),
#  ('Robert Mitchell', 747),
#  ('Cindy Lambert', 93),
#  ('Thomas Skinner', 329),
#  ('Rebecca Guerra', 565),
#  ('Dawn Allen', 911),
#  ('April Robinson DDS', 665),
#  ('Nathan Smith', 537),
#  ('Lauren Christian', 198),
#  ('Steven Mcdonald', 36),
#  ('David Carney', 48),
#  ('Donald Horton', 456),
#  ('Tracy Hardy', 430),
#  ('Joseph Carr', 401),
#  ('Luke Mcguire', 580),
#  ('Jennifer Lopez', 239),
#  ('Abigail Perez', 917),
#  ('Jason Adams', 362),
#  ('Jessica Rush', 38),
#  ('Ashley Lopez', 186),
#  ('Abigail Perez', 230),
#  ('April Robinson DDS', 971),
#  ('Mario Miller', 218),
#  ('Stacey Patton', 122),
#  ('William Rocha', 467),
#  ('Kayla Adams', 815),
#  ('Jennifer Lopez', 550),
#  ('Brian Pittman', 123),
#  ('Jon Wong', 840),
#  ('Larry Griffin', 815),
#  ('Timothy Dyer', 185),
#  ('Michael Manning', 853),
#  ('Erin Rodriguez', 914),
#  ('Olivia Wilson', 398),
#  ('Douglas Davis', 845),
#  ('Lindsay Dominguez', 816),
#  ('Stephen Hill', 725),
#  ('Jacob Obrien', 738),
#  ('Michele Jackson', 806),
#  ('Karen Dixon', 323),
#  ('Lindsay Daniels', 698),
#  ('Crystal Colon', 90),
#  ('Penny Oconnell', 314),
#  ('Nicholas Espinoza', 395),
#  ('David Elliott', 559),
#  ('Alyssa Holmes', 867),
#  ('Dawn Taylor', 84),
#  ('Scott Hobbs', 521),
#  ('Rebecca Smith', 660),
#  ('Thomas Ramirez', 643),
#  ('Kenneth Soto', 82),
#  ('Gregory Carter', 900),
#  ('Mary Greene', 788),
#  ('Scott Hobbs', 848),
#  ('Sandra Mccall DDS', 878),
#  ('Krista Richards DDS', 333),
#  ('Stacy Finley', 48),
#  ('Angela Shah', 602),
#  ('Danielle Patterson', 417),
#  ('Leah Boyd', 253),
#  ('Angela Orr', 164),
#  ('Daniel Miller', 522),
#  ('Donna Gonzalez', 511),
#  ('Laura Smith', 308),
#  ('Michael Manning', 842),
#  ('Shawn White', 575),
#  ('Susan Daniels', 503),
#  ('Alexandra Hood', 372),
#  ('Shaun Ball', 745),
#  ('David Nelson', 557),
#  ('Heather Robinson', 984),
#  ('Kathryn Thompson', 36),
#  ('Anthony Williams', 882),
#  ('Michael Manning', 629),
#  ('Nicholas Anderson', 635),
#  ('Daniel Howard', 589),
#  ('Courtney Norris', 250),
#  ('Michelle Silva', 785),
#  ('Javier Perez', 473),
#  ('Frank Ellis', 383),
#  ('Katie Anderson', 685),
#  ('Tracy Stewart', 337),
#  ('Angela Martin', 513),
#  ('Curtis Mccall', 903),
#  ('Kim Hodge', 814),
#  ('Cassie Reid', 28),
#  ('Aaron Houston', 354),
#  ('Rhonda Morris', 620),
#  ('Angela Orr', 233),
#  ('Kim Hodge', 411),
#  ('Gregory Carter', 234),
#  ('Melissa Williams', 183),
#  ('Tina Wilkinson', 580),
#  ('Joshua Stevenson', 237),
#  ('Mr. Andrew Nguyen', 975),
#  ('Richard Burns', 539),
#  ('David Lopez', 550),
#  ('Lisa Ponce', 617),
#  ('Joel Anthony II', 622),
#  ('Dawn Taylor', 65),
#  ('Mrs. Jennifer Sims', 256),
#  ('Jeffery Matthews', 645),
#  ('Cassandra Sandoval', 254),
#  ('Daniel King', 967),
#  ('Jeffrey Calhoun', 614),
#  ('Brendan Russell', 96),
#  ('Kelly Taylor', 910),
#  ('Cindy Roberson', 558),
#  ('Tanya Wilcox', 176),
#  ('Rebecca Guerra', 384),
#  ('John Grant', 688),
#  ('Cassandra Sandoval', 776),
#  ('Martha Garcia', 1),
#  ('Christopher Chambers', 430),
#  ('Kari Small', 718),
#  ('Sarah Le', 986),
#  ('Karla Robertson', 257),
#  ('Elaine Gomez', 825),
#  ('Marc Gutierrez', 551),
#  ('Carlos Parsons', 342),
#  ('Alexander Wood', 62),
#  ('Stephanie Bryant', 453),
#  ('Russell Howard', 6),
#  ('Carlos Parsons', 771),
#  ('Tamara Liu', 334),
#  ('Holly Lester', 299),
#  ('Kristy Hernandez', 514),
#  ('Christopher Hernandez', 204),
#  ('Dr. Megan Walker', 427),
#  ('Richard Davies', 174),
#  ('Angela Morris', 212),
#  ('Kristen Marshall', 449),
#  ('Eric Bridges', 330),
#  ('Deanna Herman', 449),
#  ('David Diaz', 624),
#  ('April Robinson DDS', 303),
#  ('Stephanie Mcbride', 478),
#  ('Jenna Mccarthy', 886),
#  ('Bethany Hall', 320),
#  ('Carol Garcia', 242),
#  ('Robert Liu', 790),
#  ('Angela Walker', 707),
#  ('Dennis David Jr.', 579),
#  ('Elaine Lee', 589),
#  ('Javier Perez', 528),
#  ('Ann Johnson', 615),
#  ('Gina Baker', 439),
#  ('Deanna Herman', 862),
#  ('David Scott', 100),
#  ('Paul Gamble', 522),
#  ('Jesse Gonzalez', 941),
#  ('Larry Griffin', 242),
#  ('Lynn Bush', 406),
#  ('Teresa Lee', 820),
#  ('Ellen Clark', 105),
#  ('Jill Bartlett', 897),
#  ('Hannah Brown', 413),
#  ('Andrew Becker', 310),
#  ('Dennis David Jr.', 60),
#  ('Nancy Ortiz', 186),
#  ('Elaine Lee', 126),
#  ('Matthew Kent', 387),
#  ('Hannah Norris', 46),
#  ('Jeremy Key', 325),
#  ('Brandon Edwards', 370),
#  ('Keith Harper', 505),
#  ('Tina Patterson', 472),
#  ('Kendra Barton', 507),
#  ('Ashley Moran', 119),
#  ('Tina Wilkinson', 337),
#  ('Amanda Bishop', 403),
#  ('Deborah White', 564),
#  ('Angela Trujillo', 996),
#  ('Thomas Carroll', 650),
#  ('Jaime Bridges', 313),
#  ('Antonio Evans', 421),
#  ('Jerry Gomez', 110),
#  ('Elizabeth Hayes', 206),
#  ('Jonathan Ramirez', 500),
#  ('Caleb Ibarra', 237),
#  ('John Diaz', 532),
#  ('Jill Faulkner', 175),
#  ('Natalie Adams', 756),
#  ('Victor Moore', 789),
#  ('Alexis Richards', 803),
#  ('Seth Simpson', 548),
#  ('Holly Harris', 245),
#  ('Alexandra Hood', 907),
#  ('Susan Williams', 716),
#  ('Jacob Levine', 515),
#  ('Michael Manning', 834),
#  ('Brian Pittman', 701),
#  ('Timothy Dyer', 567),
#  ('Larry Walker', 918),
#  ('William Rocha', 728),
#  ('Michelle Hall', 901),
#  ('Daniel Mitchell', 874),
#  ('Ariana Scott', 357),
#  ('Elizabeth Mccullough', 976),
#  ('Linda Parrish', 686),
#  ('Mr. Steven Rogers MD', 534),
#  ('Ryan Collins', 380),
#  ('Eric Johnson', 336),
#  ('James Harper', 352),
#  ('Kyle Clark', 957),
#  ('Ashley Lopez', 340),
#  ('Andrew Cook MD', 897),
#  ('Tamara Poole', 696),
#  ('Raymond Porter', 307),
#  ('Mark Vargas', 412),
#  ('Catherine Smith', 286),
#  ('Sarah Anderson', 227),
#  ('Cindy Lambert', 882),
#  ('Charles Cooper', 340),
#  ('Ashley Reyes', 147),
#  ('William King', 832),
#  ('Jason Sanchez', 54),
#  ('Robert Brewer', 206),
#  ('Dana Buckley', 664),
#  ('Kylie Molina', 515),
#  ('Amanda Ferguson', 551),
#  ('Lauren Christian', 617),
#  ('Mary Greene', 383),
#  ('Sarah Thornton', 857),
#  ('Juan Duarte', 962),
#  ('Valerie Mcmahon', 298),
#  ('Eric Davis', 278),
#  ('Melissa Sanders', 788),
#  ('Charles Black', 862),
#  ('John Ramos', 7),
#  ('David Diaz', 699),
#  ('Danielle Price', 480),
#  ('Victor Howard', 677),
#  ('Courtney Camacho', 248),
#  ('Misty Brown', 629),
#  ('Stephanie Bryant', 531),
#  ('Juan Bailey', 825),
#  ('Joseph Holland', 161),
#  ('Courtney Norris', 191),
#  ('Tiffany Weaver', 80),
#  ('Joshua Frye', 310),
#  ('Daniel King', 516),
#  ('Michael Carlson', 580),
#  ('Steven Mcdonald', 691),
#  ('Dennis Johnson', 663),
#  ('April Lopez', 656),
#  ('Shelly Larson', 929),
#  ('Alexis Ward', 91),
#  ('Christopher Chambers', 861),
#  ('Curtis Mccall', 553),
#  ('James Collins', 734),
#  ('Michelle Hall', 18),
#  ('Kimberly Thomas', 359),
#  ('Scott Hobbs', 523),
#  ('Paul Smith', 602),
#  ('Michelle Hall', 479),
#  ('Linda Wilcox', 967),
#  ('Joel Roberts', 703),
#  ('Lisa Simon', 686),
#  ('Bruce Johnson', 673),
#  ('Matthew Adams', 800),
#  ('Tamara Sellers', 648),
#  ('Heather Jackson', 313),
#  ('Tyler Williams', 105),
#  ('Shirley Lewis', 658),
#  ('Richard Watkins DDS', 153),
#  ('William Pennington', 564),
#  ('Anthony Carson', 594),
#  ('Melissa Barrera', 129),
#  ('Cassie Reid', 836),
#  ('Thomas Flores', 491),
#  ('Frank Watson', 121),
#  ('Elizabeth Montgomery', 295),
#  ('Amy Smith', 483),
#  ('David Nelson', 938),
#  ('William Cooper', 682),
#  ('Amber Ortega', 206),
#  ('Julian Case', 756),
#  ('Melissa Kaufman', 54),
#  ('Michael Berger', 849),
#  ('Lindsay Francis', 506),
#  ('Louis Brown', 76),
#  ('Anthony Riley', 641),
#  ('Susan Daniels', 406),
#  ('Daniel Dawson', 273),
#  ('Danielle Price', 777),
#  ('Courtney Norris', 202),
#  ('Kristy Hernandez', 494),
#  ('Olivia Keith', 870),
#  ('Jodi Reynolds', 195),
#  ('Philip Barnett', 931),
#  ('Melissa Barrera', 411),
#  ('Alyssa Cervantes', 803),
#  ('Michele Grant', 672),
#  ('Linda Wilcox', 124),
#  ('Katie Anderson', 856),
#  ('Jessica Nguyen', 685),
#  ('Ashley Gonzalez', 24),
#  ('Christine Young', 643),
#  ('Richard Martinez', 997),
#  ('Arthur Richardson', 36),
#  ('David Ross', 827),
#  ('David Diaz', 328),
#  ('Kathryn Thompson', 28),
#  ('Phillip Diaz', 931),
#  ('Jordan Simon', 433),
#  ('Chelsea Todd', 12),
#  ('Regina Cooke', 101),
#  ('Diane Pacheco', 12),
#  ('Kenneth Mclean', 63),
#  ('Deanna Herman', 571),
#  ('Cindy Lambert', 356),
#  ('Dustin Schaefer', 579),
#  ('Daniel Mitchell', 819),
#  ('Dr. Jose Friedman', 238),
#  ('Tara Harrison', 49),
#  ('Dawn Taylor', 122),
#  ('Ryan Clark', 542),
#  ('Robert Rowe', 180),
#  ('Benjamin Sharp', 654),
#  ('Victor Moore', 280),
#  ('Tanya Wilcox', 591),
#  ('Arthur Richardson', 421),
#  ('Travis Espinoza', 571),
#  ('Brian Mcdowell', 384),
#  ('Michele Jackson', 789),
#  ('Joshua Callahan', 877),
#  ('John Martinez', 971),
#  ('Anna Nguyen', 931),
#  ('Stephanie Young', 37),
#  ('William King', 65),
#  ('David Weber', 383),
#  ('Anthony Wood', 976),
#  ('Bethany Hall', 285),
#  ('Wesley Bass', 804),
#  ('Richard Watkins DDS', 761),
#  ('Elizabeth Montgomery', 720),
#  ('Rachel Travis', 65),
#  ('Kevin Miller', 608),
#  ('Jonathan Smith', 119),
#  ('Michael Rivera', 753),
#  ('Robert Brewer', 278),
#  ('Andrea Howard', 808),
#  ('Julia Reid', 735),
#  ('Amber Ortega', 241),
#  ('Kimberly Daniels', 809),
#  ('Hannah Norris', 770),
#  ('Randy Hudson', 372),
#  ('Andrew Hughes', 79),
#  ('David Scott', 694),
#  ('Jordan West', 802),
#  ('Robert Torres', 162),
#  ('Sarah Harrison', 207),
#  ('Sara Wheeler', 469),
#  ('Shannon Daniel', 681),
#  ('Daniel Mccarthy', 506),
#  ('Ashley Avila', 794),
#  ('Robert Taylor', 962),
#  ('Dean Mason', 70),
#  ('Daniel Howard', 39),
#  ('Melinda Sanchez', 345),
#  ('Susan Duarte', 228),
#  ('Mrs. Jenny Lewis', 314),
#  ('Shawn Rose', 724),
#  ('Nicole Acevedo', 264),
#  ('Jessica Garner', 669),
#  ('Ashley Reyes', 737),
#  ('Cassandra Sandoval', 665),
#  ('Jesse Bryant', 480),
#  ('Morgan Arias', 546),
#  ('Melissa Sanders', 993),
#  ('Jerry Gomez', 78),
#  ('Laura Reed', 442),
#  ('Donna Blake', 430),
#  ('William Pittman', 838),
#  ('Diamond Webb', 410),
#  ('Christopher Woods', 543),
#  ('Paul Elliott', 958),
#  ('Donald Henson', 359),
#  ('John Martinez', 790),
#  ('Michael Wilson', 901),
#  ('Kayla Adams', 424),
#  ('Jason Adams', 154),
#  ('Deborah White', 626),
#  ('Jacob Deleon', 649),
#  ('Kenneth Mclean', 86),
#  ('Julie Sanders', 926),
#  ('Justin Gaines', 482),
#  ('Nancy Shaw', 852),
#  ('Dean Mason', 290),
#  ('David Ross', 500),
#  ('Dr. Kevin Nichols DDS', 379),
#  ('Curtis Mccall', 898),
#  ('Philip Jackson', 526),
#  ('Karen Dixon', 276),
#  ('Shelby Lopez', 359),
#  ('Jamie English', 395),
#  ('Adam Scott', 140),
#  ('Michele West', 625),
#  ('Jeremiah Clayton', 737),
#  ('Christine Turner', 248),
#  ('Mario Miller', 122),
#  ('Laura Payne', 124),
#  ('Gary Baxter', 311),
#  ('Matthew Kent', 425),
#  ('Sherri Beck', 870),
#  ('Kristi Banks', 324),
#  ('Derek Brown', 551),
#  ('Zachary Weiss', 176),
#  ('Louis Gonzales', 2),
#  ('Mrs. Peggy Alexander', 233),
#  ('James Velazquez', 313),
#  ('Tracy Stewart', 564),
#  ('Heather Guerrero', 68),
#  ('Bob Taylor', 407),
#  ('Angela Palmer', 235),
#  ('Lindsay Dominguez', 343),
#  ('Kristin Lin', 795),
#  ('Elizabeth Webb', 232),
#  ('Amy Smith', 424),
#  ('Joshua Stevenson', 232),
#  ('Karla Robertson', 392),
#  ('Andrea Reed', 637),
#  ('Bethany Arnold DDS', 729),
#  ('Darrell Patterson', 737),
#  ('Autumn Horton', 798),
#  ('Brendan Russell', 284),
#  ('Elizabeth Mccullough', 260),
#  ('Linda Wilcox', 616),
#  ('Angela Pace', 525),
#  ('Michele Oconnor', 220),
#  ('Melissa Berry', 995),
#  ('Michael Wilson', 931),
#  ('Lisa Clark', 870),
#  ('Patrick Clayton III', 915),
#  ('Tara Gonzalez', 438),
#  ('Gabriel Mccoy', 67),
#  ('Keith Rosales', 253),
#  ('Gerald Scott', 390),
#  ('Christopher Byrd', 899),
#  ('Jonathan Berry', 751),
#  ('Daniel King', 569),
#  ('Evan Moses', 616),
#  ('Kristy Hernandez', 89),
#  ('Manuel Rodriguez', 768),
#  ('Paul Johnson', 665),
#  ('Troy Barrera', 663),
#  ('Amber Moore', 124),
#  ('Brian Charles', 394),
#  ('Monica Perry', 772),
#  ('Amanda Parks', 131),
#  ('Madison Harrison', 926),
#  ('Mr. Christopher Smith MD', 321),
#  ('Justin Gaines', 747),
#  ('Jason Carter', 880),
#  ('Patrick Parker', 52),
#  ('Amanda Bishop', 363),
#  ('Theresa Chambers', 346),
#  ('Holly Mason', 980),
#  ('Patrick Adams', 31),
#  ('Mary Lewis', 594),
#  ('Kimberly Ramirez', 435),
#  ('Susan Daniels', 101),
#  ('Daniel Taylor', 597),
#  ('Laura Reed', 385),
#  ('Dr. Brett Johnson', 542),
#  ('Frank Watson', 336),
#  ('James Marsh', 27),
#  ('Leslie Brooks', 403),
#  ('Gregory Carpenter', 138),
#  ('Linda Parrish', 106),
#  ('Laura Smith', 992),
#  ('Natalie Zuniga', 633),
#  ('James Velasquez', 479),
#  ('Kevin Russell', 501),
#  ('David Scott', 770),
#  ('Pamela Nichols', 878),
#  ('Tina Park', 481),
#  ('William King', 230),
#  ('Ronald Franklin', 137),
#  ('Elizabeth Jones', 796),
#  ('Rachel Madden', 145),
#  ('John Velasquez', 152),
#  ('Anthony Flores', 596),
#  ('Amber Ortega', 846),
#  ('Eduardo Scott', 808),
#  ('David Lewis', 641),
#  ('Deanna Rodriguez', 113),
#  ('Amy Rhodes', 210),
#  ('Tamara Sellers', 342),
#  ('William Cooper', 246),
#  ('Rebecca Weaver', 390),
#  ('Rachel Madden', 570),
#  ('Donald Horton', 7),
#  ('Lisa Simon', 51),
#  ('Tiffany Woods', 465),
#  ('Courtney Smith', 882),
#  ('Cassie Reid', 929),
#  ('Jenna Mccarthy', 720),
#  ('Tara Gonzalez', 718),
#  ('Stephanie Gonzalez', 847),
#  ('Joel Roberts', 373),
#  ('Andrew Hughes', 702),
#  ('Hannah Cochran', 441),
#  ('Marvin Garcia', 508),
#  ('Rebecca Guerra', 801),
#  ('Stephanie West', 131),
#  ('Robert Miller', 997),
#  ('Heather Carlson', 413),
#  ('David Jones', 50),
#  ('Craig Garcia', 755),
#  ('Jack Owens', 870),
#  ('Ralph Smith', 524),
#  ('Nancy Baker', 452),
#  ('Stephanie Lopez', 771),
#  ('Benjamin Ramirez Jr.', 229),
#  ('Brian Charles', 341),
#  ('Kenneth Wade', 157),
#  ('Johnny Craig', 743),
#  ('Crystal Johnson', 400),
#  ('Jonathan Ramirez', 170),
#  ('Travis Espinoza', 622),
#  ('James Juarez', 410),
#  ('Mrs. Peggy Alexander', 991),
#  ('Nicholas Owens', 214),
#  ('Tyler Moore', 439),
#  ('Jessica Phillips', 741),
#  ('Anthony Riley', 456),
#  ('Michael White', 201),
#  ('Andrew Santos', 17),
#  ('Jacqueline Williams', 48),
#  ('Dana Carpenter', 829),
#  ('Dennis David Jr.', 423),
#  ('Michelle Wilson', 533),
#  ('Leslie Brooks', 44),
#  ('Stacy Finley', 851),
#  ('Kelly Moss', 905),
#  ('Troy Bell', 146),
#  ('Matthew Kent', 874),
#  ('Mark Vargas', 716),
#  ('Christopher Woods', 973),
#  ('Amanda Flowers', 462),
#  ('Taylor Flores', 390),
#  ('Kristina Watts', 299),
#  ('Sally Williams', 370),
#  ('Rebecca Alvarez', 102),
#  ('Mary Schneider', 913),
#  ('Margaret Gomez', 839),
#  ('Charles Munoz', 696),
#  ('Kara Ramirez', 531),
#  ('Karen Owen', 215),
#  ('Tamara Liu', 11),
#  ('Danielle Price', 658),
#  ('Brittany Patrick', 774),
#  ('Eric Ward', 2),
#  ('Nichole Harris', 293),
#  ('Amy Yang', 925),
#  ('David Ross', 516),
#  ('Frank Ellis', 944),
#  ('Dawn Taylor', 858),
#  ('Jeffery Green', 592),
#  ('Benjamin Martin', 749),
#  ('John Martinez', 796),
#  ('Joe Morales', 54),
#  ('Juan Blackburn', 913),
#  ('Richard Watkins DDS', 904),
#  ('Andrew Santos', 889),
#  ('Lisa Cox', 645),
#  ('Christopher Hernandez', 976),
#  ('Shirley Lewis', 824),
#  ('Michelle Riggs', 378),
#  ('Joseph Nelson', 243),
#  ('David Nelson', 946),
#  ('April Mcguire', 922),
#  ('Antonio Potter', 973),
#  ('Robin Gomez', 866),
#  ('Cassie Reid', 858),
#  ('Angela Walker', 88),
#  ('Stephanie Mcbride', 771),
#  ('Mary Perry', 740),
#  ('Traci Williams', 563),
#  ('Paula Schneider', 672),
#  ('Jeremy White', 823),
#  ('Mary Schneider', 174),
#  ('Mary Moss', 936),
#  ('Jacqueline Rodriguez', 254),
#  ('John Roberts', 674),
#  ('Michael Brown', 569),
#  ('Tamara Liu', 994),
#  ('Monica Perry', 564),
#  ('Evan Moses', 980),
#  ('Jennifer Fuller', 540),
#  ('Mrs. Jenny Lewis', 226),
#  ('Richard Cruz', 232),
#  ('Amanda Smith', 656),
#  ('Dennis Johnson', 310),
#  ('Joseph Higgins', 969),
#  ('Andrea Howard', 65),
#  ('Randy Hudson', 486),
#  ('Brianna Wright', 766),
#  ('Amanda Ferguson', 536),
#  ('Jennifer Conner', 562),
#  ('Joseph Carr', 154),
#  ('Bruce Cole', 696),
#  ('Olivia Vasquez', 273),
#  ('Lori Martinez', 528),
#  ('Mr. Jason Johnson DVM', 391),
#  ('Sara Bell', 84),
#  ('Sarah Anderson', 948),
#  ('Paula Vance', 126),
#  ('Linda Green', 584),
#  ('Scott Good', 193),
#  ('Elizabeth Thomas', 338),
#  ('Kelly Burch', 338),
#  ('Andrea Reed', 513),
#  ('Janet Roman', 382),
#  ('Sally Herring', 290),
#  ('Andrew Brown', 254),
#  ('Alicia Walsh', 700),
#  ('Julian Case', 847),
#  ('Michael Boyd', 370),
#  ('Gabriel Parks', 122),
#  ('Kenneth Patterson', 833),
#  ('Jeffery Brown', 982),
#  ('Michael Carlson', 608),
#  ('Meredith Rasmussen', 768),
#  ('Kari Small', 162),
#  ('Elizabeth Mcdonald', 601),
#  ('Larry Walker', 492),
#  ('Michael Martin', 337),
#  ('Melanie Reyes', 558),
#  ('Dylan Santiago Jr.', 16),
#  ('Amy Rhodes', 495),
#  ('Jordan Moreno', 664),
#  ('Janet George', 780),
#  ('Stephanie Clark', 369),
#  ('Mary Moss', 576),
#  ('Jesus Campbell', 775),
#  ('William Lewis', 236),
#  ('Curtis Mccall', 636),
#  ('Mrs. Jennifer Sims', 948),
#  ('Victoria Moses', 761),
#  ('Jennifer Conner', 183),
#  ('Rebecca Bennett', 233),
#  ('Michelle Riggs', 804),
#  ('Joel Miller', 401),
#  ('Jessica Phillips', 301),
#  ('Scott Edwards', 941),
#  ('Katrina Lee', 520),
#  ('Paul Smith', 792),
#  ('Michael Thompson', 59),
#  ('Robert Mitchell', 733),
#  ('Joseph Higgins', 895),
#  ('Mary Lewis', 94),
#  ('Russell Ruiz', 164),
#  ('Shannon Cooper', 177),
#  ('John Velasquez', 546),
#  ('Jonathan Elliott', 660),
#  ('William Brown', 632),
#  ('Alejandra Esparza', 731),
#  ('Bonnie Garcia', 642),
#  ('Brenda Joseph', 510),
#  ('Andrew Cook MD', 488),
#  ('Douglas Davis', 779),
#  ('John King', 895),
#  ('Karen Ingram', 887),
#  ('Jeffery Matthews', 396),
#  ('Stephanie West', 155),
#  ('Brian Townsend', 610),
#  ('Elizabeth Thomas', 981),
#  ('Natalie Moore', 304),
#  ('Lisa Tyler', 577),
#  ('James Juarez', 956),
#  ('Mrs. Jenny Lewis', 885),
#  ('Joseph Payne', 194),
#  ('Austin Turner', 870),
#  ('Donald Horton', 616),
#  ('Michael Manning', 676),
#  ('Christopher Woodard', 688),
#  ('Michael Gibson', 815),
#  ('Diane Pacheco', 805),
#  ('Jessica Nguyen', 616),
#  ('Michael Boyd', 39),
#  ('Russell Ruiz', 666),
#  ('Duane Carey', 304),
#  ('Chelsea Todd', 79),
#  ('Jeffrey Calhoun', 240),
#  ('Dr. Michael Shelton MD', 326),
#  ('Cory Reyes', 982),
#  ('Meredith Rasmussen', 790),
#  ('James Roberts', 96),
#  ('Janet Dean', 523),
#  ('Jon Johnson', 325),
#  ('Jonathan Elliott', 407),
#  ('Eric Johnson', 723),
#  ('Nicole Johnson', 389),
#  ('Nancy Ortiz', 845),
#  ('Warren Sanders', 496),
#  ('Daniel King', 374),
#  ('Donna Blake', 49),
#  ('Sara Bell', 992),
#  ('Eric Johnson', 638),
#  ('Kristen Marshall', 140),
#  ('Rachel Travis', 52),
#  ('Richard Park', 732),
#  ('Traci Williams', 37),
#  ('Lynn Bush', 22),
#  ('Paul Smith', 891),
#  ('Tracy Richardson', 367),
#  ('Joshua Smith', 396),
#  ('Tony Roberts', 619),
#  ('Kendra Massey', 883),
#  ('Daniel Scott', 827),
#  ('Nicholas Espinoza', 452),
#  ('Anthony Warner', 618),
#  ('Debra Mccarty', 750),
#  ('Nicholas Anderson', 938),
#  ('Virginia Brewer', 544),
#  ('Logan Johnson', 732),
#  ('Craig Coffey', 541),
#  ('Kimberly Carr', 370),
#  ('Daniel Mitchell', 348),
#  ('Jonathan Berry', 981),
#  ('Thomas Kirk', 360),
#  ('Teresa Lee', 781),
#  ('Anna Nguyen', 521),
#  ('Rebecca Smith', 221),
#  ('Christina Smith', 865),
#  ('Mitchell Jones', 715),
#  ('Melissa Kaufman', 360),
#  ('Janet Dean', 820),
#  ('Warren Sanders', 427),
#  ('Robert Torres', 517),
#  ('Sarah Greer', 94),
#  ('Walter Roberts', 986),
#  ('Daniel Dawson', 947),
#  ('Robert Craig', 125),
#  ('Dwayne Rojas', 314),
#  ('Gregory Gregory', 134),
#  ('Mitchell Jones', 604),
#  ('Matthew Patel', 413),
#  ('Heather Collier', 548),
#  ('Kevin Russell', 771),
#  ('Phillip Diaz', 244),
#  ('Victor May', 929),
#  ('Chloe Moss', 523),
#  ('Deanna Herman', 862),
#  ('Dean Mason', 926),
#  ('Brian Townsend', 545),
#  ('Brian Bates', 127),
#  ('Christopher Walker', 405),
#  ('Pamela Jones', 328),
#  ('Melinda Sanchez', 196),
#  ('Nancy Shaw', 317),
#  ('Caleb Ibarra', 530),
#  ('Justin Patterson', 357),
#  ('Elizabeth Sanchez', 179),
#  ('Jordan West', 59),
#  ('Kurt Ware', 910),
#  ('Vanessa Johnson', 414),
#  ('Anthony Warner', 537),
#  ('Dr. Michael Shelton MD', 487),
#  ('Robert Taylor', 21),
#  ('Elizabeth Mccullough', 528),
#  ('Tony Roberts', 973),
#  ('Brandon Moore', 281),
#  ('Cheryl Lopez', 95),
#  ('Lindsay Francis', 78),
#  ('Keith Rosales', 230),
#  ('Robert Taylor', 639),
#  ('Jacqueline Rodriguez', 356),
#  ('Brian Juarez', 631),
#  ('Courtney Smith', 690),
#  ('Kristen Marshall', 284),
#  ('Scott Mccarty', 460),
#  ('Juan Duarte', 256),
#  ('Shelby Lopez', 888),
#  ('Jon Wong', 120),
#  ('Christopher Woodard', 582),
#  ('Keith Harper', 161),
#  ('Brian Townsend', 86),
#  ('Nicole Acevedo', 294),
#  ('Julia Craig', 804),
#  ('Brian Charles', 138),
#  ('David Jones', 488),
#  ('Shannon Webb', 34),
#  ('Victoria Freeman', 351),
#  ('Angela Orr', 284),
#  ('Brandy Griffin', 795),
#  ('Shaun Ball', 163),
#  ('Jamie Ortiz', 284),
#  ('Ellen Clark', 951),
#  ('Melissa Barrera', 948),
#  ('Angela Shah', 213),
#  ('Thomas Lynn', 774),
#  ('Elizabeth Thomas', 240),
#  ('Rebecca Bennett', 948),
#  ('Elaine Gomez', 409),
#  ('Melissa Stephens', 580),
#  ('Dr. Megan Walker', 710),
#  ('Mary Greene', 597),
#  ('Marilyn Duarte', 364),
#  ('Christopher Shepherd', 710),
#  ('Nichole Harris', 388),
#  ('Sandra Johnson', 796),
#  ('Steven Robinson', 219),
#  ('Andrew Santos', 401),
#  ('Patrick Smith', 997),
#  ('Derek Guzman', 892),
#  ('Rachel Lee', 684),
#  ('Adam Williams', 686),
#  ('Dr. Jose Friedman', 132),
#  ('Deborah White', 75),
#  ('Jennifer Smith', 595),
#  ('Dana Buckley', 159),
#  ('Thomas Ortiz', 143),
#  ('Jeremy Bradford', 893),
#  ('Melissa Barrera', 667),
#  ('Amanda Copeland', 913),
#  ('Bonnie Carroll', 672),
#  ('Brianna Wright', 966),
#  ('Jonathan Smith', 330),
#  ('Dr. Jose Friedman', 797),
#  ('William Pennington', 724),
#  ('Sarah Thornton', 802),
#  ('Erin Davis', 491),
#  ('Jason Carter', 140),
#  ('Victor May', 869),
#  ('Jennifer Hansen', 34),
#  ('Gregory Carpenter', 887),
#  ('Frank Ellis', 184),
#  ('Cesar Mcconnell', 66),
#  ('Lynn Bush', 458),
#  ('Erin Davis', 251),
#  ('Mary Lewis', 226),
#  ('Carolyn Cooper', 640),
#  ('Jacob Wilson', 248),
#  ('Gabriel Mccoy', 287),
#  ('Stephanie Lopez', 483),
#  ('Mitchell Jones', 956),
#  ('Paige Lucas DVM', 686),
#  ('Jacob Jimenez', 252),
#  ('Paul Gamble', 481),
#  ('Elizabeth Hayes', 24),
#  ('Crystal Johnson', 475),
#  ('Jordan Simon', 318),
#  ('Nicholas Owens', 764),
#  ('Elizabeth Mendez', 571),
#  ('Curtis Love', 393),
#  ('Jessica Nguyen', 579),
#  ('Amy Green', 392),
#  ('Ryan Clark', 366),
#  ('Alexandra Hood', 591),
#  ('Terrance Thomas', 410),
#  ('Tiffany Miller', 277),
#  ('Kathleen Jacobs', 621),
#  ('Bethany Arnold DDS', 903),
#  ('Elizabeth Gallagher', 307),
#  ('Cindy Lambert', 428),
#  ('Joshua Rivera', 655),
#  ('Kim Hodge', 904),
#  ('Amy Rhodes', 645),
#  ('Jonathan Smith', 567),
#  ('Gail Patrick', 348),
#  ('Leslie Brooks', 914),
#  ('Joshua Rivera', 505),
#  ('Victoria Moses', 1),
#  ('Amber Daniel', 803),
#  ('Robert Torres', 961),
#  ('Autumn Horton', 617),
#  ('Marc Gutierrez', 472),
#  ('Elizabeth Hayes', 414),
#  ('Christopher Garcia', 772),
#  ('Angela Palmer', 901),
#  ('Amanda Bishop', 868),
#  ('Benjamin Sharp', 93),
#  ('Kayla Adams', 263),
#  ('Tracy Flores', 691),
#  ('Jordan West', 254),
#  ('Jack Owens', 286),
#  ('Amy Rhodes', 269),
#  ('Sandra Cunningham', 500),
#  ('Robert Haynes', 878),
#  ('Holly Mason', 283),
#  ('Isabel Gregory', 352),
#  ('John Martinez', 249),
#  ('Joshua Callahan', 338),
#  ('Nancy Shaw', 269),
#  ('William King', 257),
#  ('Christopher Hernandez', 397),
#  ('April Walker', 308),
#  ('Jacqueline Rodriguez', 108),
#  ('Bonnie Carroll', 710),
#  ('Crystal Delgado', 157),
#  ('Scott Mccarty', 176),
#  ('Mario Jones', 683),
#  ('Holly Wright', 446),
#  ('Michael Thompson', 427),
#  ('Katherine Solomon', 834),
#  ('Katrina Lee', 440),
#  ('Shirley Lewis', 821),
#  ('Russell Howard', 809),
#  ('Austin Turner', 835),
#  ('Dakota Morrison', 664),
#  ('Paula Vance', 254),
#  ('Derek Guzman', 342),
#  ('Jerry Green', 189),
#  ('Shannon Flores', 542),
#  ('April Walker', 669),
#  ('Gerald Scott', 728),
#  ('Jamie Martinez', 216),
#  ('Austin Turner', 104),
#  ('Stephanie Young', 817),
#  ('Jessica Rush', 678),
#  ('Thomas Lynn', 908),
#  ('Alicia Walsh', 557),
#  ('Gregory Carter', 386),
#  ('Jennifer Faulkner', 61),
#  ('Nicole Acevedo', 966),
#  ('Tina Park', 719),
#  ('Leah Boyd', 616),
#  ('Tony Roberts', 411),
#  ('Wanda Johnson', 412),
#  ('William Dawson', 499),
#  ('James Marsh', 228),
#  ('Matthew Adams', 291),
#  ('Ashley Lopez', 394),
#  ('Diane Pacheco', 253),
#  ('Craig Coffey', 409),
#  ('Elaine Lee', 354),
#  ('Latoya Ross', 163),
#  ('Ryan Moore', 883),
#  ('Christopher Woodard', 418),
#  ('Patrick Norris', 540),
#  ('Tyler Williams', 157),
#  ('Gabriel Parks', 940),
#  ('Mrs. Peggy Alexander', 338),
#  ('Lindsey Weaver', 585),
#  ('Nicole Acevedo', 672),
#  ('Amber Daniel', 823),
#  ('Michael Alexander', 859),
#  ('Amanda Ferguson', 628),
#  ('Jacqueline Smith', 830),
#  ('Julie Lewis', 947),
#  ('Anthony Wood', 270),
#  ('Jaime Bridges', 177),
#  ('Shannon Webb', 334),
#  ('Michael Lopez', 348),
#  ('Morgan Arias', 408),
#  ('Ryan Huber', 742),
#  ('Linda Wilcox', 808),
#  ('Joseph Mendez', 10),
#  ('Susan Phillips', 667),
#  ('Stephanie Harris', 864),
#  ('Alexander Wood', 102),
#  ('Meredith Rasmussen', 44),
#  ('Benjamin Sharp', 697),
#  ('Keith Rosales', 743),
#  ('Latoya Ross', 148),
#  ('Brian Bates', 278),
#  ('Ashley Lopez', 848),
#  ('Matthew Rios', 912),
#  ('Rachel Williams', 816),
#  ('Patrick Smith', 716),
#  ('Kim Hodge', 184),
#  ('Donald Horton', 169),
#  ('Kim Johnson', 995),
#  ('Michelle Wilson', 703),
#  ('Denise Burke', 525),
#  ('Daniel Scott', 472),
#  ('Erin Rodriguez', 808),
#  ('Jay Logan', 924),
#  ('Wanda Johnson', 202),
#  ('Ryan Collins', 726),
#  ('Thomas Flores', 927),
#  ('Jeffrey Merritt', 999),
#  ('Sarah Le', 362),
#  ('Dustin Flynn', 366),
#  ('Bradley Martinez', 857),
#  ('Jeffery Matthews', 504),
#  ('Sherry Potter', 285),
#  ('Dwayne Rojas', 859),
#  ('Chloe Moss', 512),
#  ('Jonathan Elliott', 401),
#  ('Alexis Richards', 949),
#  ('Troy Barrera', 305),
#  ('Michele Oconnor', 445),
#  ('Karen Johnson', 359),
#  ('Eric Davis', 432),
#  ('Sara Bell', 201),
#  ('Laura Reed', 490),
#  ('Melissa Barrera', 709),
#  ('Mr. Zachary Hicks', 442),
#  ('Dean Mason', 723),
#  ('Randy Hudson', 59),
#  ('Benjamin Cooper', 532),
#  ('Jason Joseph', 970),
#  ('Stephanie Gonzalez', 302),
#  ('Stephen Hicks', 519),
#  ('John Diaz', 499),
#  ('Lori Wood', 508),
#  ('Christopher Walker', 935),
#  ('Jack Pratt', 161),
#  ('Paul Good', 984),
#  ('Andrew Moore', 146),
#  ('Joshua Callahan', 463),
#  ('Justin Acosta', 381),
#  ('David Hull', 80),
#  ('Jeremy Key', 123),
#  ('John Garza', 437),
#  ('Katrina Lee', 797),
#  ('Jennifer Oneill', 350),
#  ('Marilyn Duarte', 352),
#  ('Nancy Baker', 94),
#  ('Holly Wright', 549),
#  ('Patrick Adams', 511),
#  ('James Velasquez', 802),
#  ('Sarah Thornton', 985),
#  ('Dustin Flynn', 364),
#  ('Derek Brown', 906),
#  ('Tom Flores', 863),
#  ('Ronald Franklin', 683),
#  ('Evan Moses', 477),
#  ('Derek Brown', 70),
#  ('Christopher Russell', 954),
#  ('Jacob Jimenez', 420),
#  ('Jennifer Smith', 966),
#  ('Sabrina Cruz', 248),
#  ('Paul Johnson', 177),
#  ('Lawrence Rodriguez', 990),
#  ('Duane Carey', 426),
#  ('Denise Burke', 598),
#  ('John Roberts', 107),
#  ('Amanda Sellers', 952),
#  ('Melissa Berry', 281),
#  ('Jamie Ortiz', 314),
#  ('Jeffery Brown', 999),
#  ('Zachary Weiss', 453),
#  ('Jamie Ortiz', 215),
#  ('Barbara Rivera', 452),
#  ('Tiffany Miller', 76),
#  ('Mary Nelson', 355),
#  ('Daniel King', 436),
#  ('Sherry Potter', 542),
#  ('Jennifer Hogan', 566),
#  ('Alicia Walsh', 851),
#  ('Lynn Bush', 862),
#  ('Leah Boyd', 510),
#  ('Stephanie Williamson', 696),
#  ('Amanda Parks', 784),
#  ('Jon Johnson', 187),
#  ('Robert Craig', 880),
#  ('Chris Johnson', 917),
#  ('Arthur Richardson', 186),
#  ('Christina French', 720),
#  ('Stephen Hunt', 967),
#  ('Tracy Hardy', 58),
#  ('Bruce Porter', 675),
#  ('Mario Miller', 178),
#  ('Jennifer Jackson', 53),
#  ('Sharon Russell', 455),
#  ('Joshua Frye', 655),
#  ('Juan Blackburn', 535),
#  ('Robert Lynch', 997),
#  ('Dustin Flynn', 731),
#  ('Jill Barnes', 693),
#  ('William Lewis', 504),
#  ('Tammy Garcia', 398),
#  ('Daniel Scott', 282),
#  ('Angela Orr', 125),
#  ('Kevin Richardson', 482),
#  ('David Long', 392),
#  ('Kimberly Alvarado', 783),
#  ('Jacob Deleon', 640),
#  ('Lisa Cox', 993),
#  ('Antonio Evans', 581),
#  ('John Garza', 606),
#  ('Jonathan Ramirez', 292),
#  ('Sean Johnson', 762),
#  ('Elaine Gomez', 630),
#  ('Sharon Russell', 479),
#  ('Misty Brown', 561),
#  ('Jonathan Berry', 259),
#  ('Lee Brady', 472),
#  ('Terrance Thomas', 426),
#  ('Kimberly Carr', 684),
#  ('Dylan Santiago Jr.', 542),
#  ('Loretta Evans', 243),
#  ('Crystal Delgado', 53),
#  ('Jason Carter', 499),
#  ('Eric Garcia', 23),
#  ('Thomas Kirk', 973),
#  ('Lisa Zimmerman', 192),
#  ('John Velasquez', 920),
#  ('David Boyd', 252),
#  ('Courtney Smith', 765),
#  ('Monica Perry', 326),
#  ('Randy King', 634),
#  ('Tiffany Weaver', 451),
#  ('Paul Smith', 35),
#  ('Sherri Beck', 900),
#  ('Donna Gonzalez', 773),
#  ('Tyler Murphy', 760),
#  ('Jack Pratt', 507),
#  ('Regina Cooke', 346),
#  ('Ralph Smith', 106),
#  ('Jennifer Simpson', 155),
#  ('Ryan Porter', 592),
#  ('Christina French', 439),
#  ('Kyle Clark', 520),
#  ('Nicole Johnson', 414),
#  ('Dr. John Martinez', 647),
#  ('Regina Cooke', 908),
#  ('Tracy Stewart', 639),
#  ('Amanda Sellers', 738),
#  ('Ronald Franklin', 350),
#  ('Todd Cooper', 150),
#  ('Gabriel Parks', 938),
#  ('Lisa Ferguson', 739),
#  ('Kaitlin Johnson', 27),
#  ('Karla Robertson', 838),
#  ('Marilyn Duarte', 349),
#  ('Melinda Cox', 445),
#  ('Rachel Lee', 2),
#  ('Melissa Kaufman', 494),
#  ('Janet Dean', 549),
#  ('Samantha Lewis', 349),
#  ('Miss Anita Young', 558),
#  ('Deanna Rodriguez', 738),
#  ('Kara Ramirez', 634),
#  ('Justin Patterson', 725),
#  ('Logan Medina', 242),
#  ('Sherri Nguyen', 712),
#  ('Joseph Carr', 76),
#  ('Aaron Houston', 666),
#  ('Deanna Brooks', 908),
#  ('Julie Love', 855),
#  ('Heather Robinson', 498),
#  ('Taylor Flores', 281),
#  ('John Ramos', 410),
#  ('David Nelson', 993),
#  ('Amanda Copeland', 141),
#  ('Joel Miller', 697),
#  ('Bruce Cole', 11),
#  ('Ian Daniels', 218),
#  ('Rebecca Rivera', 831),
#  ('Holly Wright', 702),
#  ('Chris Johnson', 215),
#  ('Robert Haynes', 990),
#  ('Jason Johnson', 526),
#  ('Andrew Cook MD', 922),
#  ('Justin Acosta', 491),
#  ('Karen Johnson', 149),
#  ('Robert Howard', 39),
#  ('Samantha Thompson', 962),
#  ('Nicole Lee', 299),
#  ('John Mueller', 190),
#  ('Karen Ingram', 943),
#  ('Ashley Jackson', 900),
#  ('Raymond Porter', 98),
#  ('Andrew Snyder', 524),
#  ('Michael Rivera', 142),
#  ('Warren Sanders', 25),
#  ('William Wheeler', 909),
#  ('Krista Richards DDS', 138),
#  ('Randy King', 903),
#  ('Brian Charles', 599),
#  ('Robert Haynes', 328),
#  ('David Ross', 537),
#  ('Juan Blackburn', 307),
#  ('Timothy Blackburn', 818),
#  ('Tyler Tucker', 623),
#  ('Dylan Alexander', 197),
#  ('Steve Sanders', 628),
#  ('Joshua Stevenson', 732),
#  ('Daniel Brown', 638),
#  ('Kurt Ware', 423),
#  ('Dr. David Gallagher PhD', 352),
#  ('Jessica Rush', 440),
#  ('Dennis Peck', 749),
#  ('Mary Valentine', 267),
#  ('Tonya Smith', 358),
#  ('Lisa Ferguson', 427),
#  ('Jonathan Berry', 363),
#  ('Amanda Copeland', 256),
#  ('Jennifer White', 329),
#  ('Stephen Hicks', 93),
#  ('Leslie Collins', 99),
#  ('Richard Martinez', 690),
#  ('Jordan Simon', 787),
#  ('Jessica Phillips', 966),
#  ('Adam Williams', 663),
#  ('Natalie Moore', 554),
#  ('Amber Anderson', 482),
#  ('Matthew Hopkins', 490),
#  ('Shawn Simon', 706),
#  ('Jordan West', 164),
#  ('David Lopez', 654),
#  ('Michael Alexander', 268),
#  ('Andrew Cook MD', 688),
#  ('Matthew Humphrey', 742),
#  ('Deborah Armstrong', 178),
#  ('Mary Bishop', 128),
#  ('David Cooper', 10),
#  ('Tamara Liu', 181),
#  ('Mr. Jason Johnson DVM', 885),
#  ('Bruce Johnson', 208),
#  ('Danielle Hickman', 54),
#  ('Anthony Riley', 589),
#  ('Adam Mitchell', 674),
#  ('Jeffery Matthews', 633),
#  ('Christopher Garcia', 588),
#  ('Benjamin Martin', 204),
#  ('Bruce Cole', 96),
#  ('Ashley Jackson', 940),
#  ('Chad Lee', 509),
#  ('David Elliott', 70),
#  ('Robert Brewer', 237),
#  ('Adam Scott', 920),
#  ('Philip Jackson', 688),
#  ('David Bond', 151),
#  ('Sara Bell', 968),
#  ('Matthew Hopkins', 412),
#  ('Katherine Li', 600),
#  ('Nicholas Owens', 193),
#  ('Elizabeth Jones', 811),
#  ('James Velasquez', 176),
#  ('Christopher Russell', 88),
#  ('Matthew White', 259),
#  ('Rebecca Martinez', 837),
#  ('Anthony Flores', 333),
#  ('Isabel Gregory', 202),
#  ('Amanda Bright', 298),
#  ('Susan Daniels', 847),
#  ('Donald Horton', 94),
#  ('Stacey Patton', 482),
#  ('Dennis David Jr.', 613),
#  ('Scott Good', 84),
#  ('Nicholas Perez', 212),
#  ('Jesus Campbell', 878),
#  ('Dana Carpenter', 674),
#  ('Andrew Cook MD', 136),
#  ('Dawn Taylor', 491),
#  ('Lori Martinez', 320),
#  ('Richard Watkins DDS', 774),
#  ('Isabel Gregory', 627),
#  ('Alyssa Holmes', 891),
#  ('Teresa Lee', 366),
#  ('Michael Berger', 666),
#  ('Emily Hamilton', 424),
#  ('Thomas Kirk', 568),
#  ('Christopher Woodard', 677),
#  ('Christopher Woodard', 488),
#  ('Nicholas Reed', 630),
#  ('Dr. Dillon Robinson', 320),
#  ('Lori Smith', 337),
#  ('Curtis Mccall', 999),
#  ('Mary Lewis', 137),
#  ('Diamond Webb', 580),
#  ('Jonathan King', 138),
#  ('Leslie Brooks', 831),
#  ('Michael Martin', 62),
#  ('Amanda Copeland', 542),
#  ('John Garza', 138),
#  ('Kenneth Wade', 274),
#  ('Andrea Reed', 492),
#  ('Michael Phillips', 486),
#  ('Heather Lee', 342),
#  ('Tiffany Woods', 624),
#  ('Latoya Ross', 330),
#  ('John Garza', 253),
#  ('Michael Lang', 496),
#  ('Mrs. Brittany Wade DVM', 81),
#  ('Cesar Mcconnell', 432),
#  ('Julie Woodard', 830),
#  ('Jacqueline Rodriguez', 200),
#  ('Melissa Stephens', 18),
#  ('Kathryn Thompson', 855),
#  ('Timothy Kelly', 212),
#  ('Jeffery Brown', 601),
#  ('David Hull', 514),
#  ('Lisa Ferguson', 89),
#  ('Frank Ellis', 118),
#  ('Jeffrey Morrow', 718),
#  ('Jason Carter', 569),
#  ('Robert Liu', 521),
#  ('John Ramos', 16),
#  ('Anthony Riley', 479),
#  ('David Nelson', 375),
#  ('Jesse Johnson', 697),
#  ('Cindy Lambert', 632),
#  ('Robert Rowe', 728),
#  ('Nicole Edwards', 701),
#  ('Bryce Reeves', 993),
#  ('Cindy Lambert', 347),
#  ('Heather Hernandez', 579),
#  ('Scott Edwards', 37),
#  ('Joshua Rivera', 931),
#  ('Jennifer Hogan', 383),
#  ('Gerald Scott', 424),
#  ('Michael Cruz', 962),
#  ('Amber Moore', 708),
#  ('Stephanie Lopez', 868),
#  ('Elizabeth Gallagher', 498),
#  ('Daniel Brown', 154),
#  ('Heather Hernandez', 916),
#  ('Michael Jones', 309),
#  ('Joseph Espinoza', 571),
#  ('Tina Stevens', 706),
#  ('Lisa Tyler', 576),
#  ('Patrick Adams', 707),
#  ('Danielle Perry', 665),
#  ('Patrick Norris', 103),
#  ('Sharon Russell', 13),
#  ('Justin Patterson', 1000),
#  ('Sara Bell', 350),
#  ('Adam Caldwell', 457),
#  ('Matthew Miranda', 873),
#  ('Laura Miller', 902),
#  ('Matthew Rios', 168),
#  ('Katie Anderson', 965),
#  ('Travis Lee', 946),
#  ('Linda Frost', 49),
#  ('Joel Miller', 959),
#  ('Stacy Finley', 220),
#  ('Patricia Fisher', 865),
#  ('Jonathan Berry', 238),
#  ('Angela Mccoy', 899),
#  ('William Wheeler', 975),
#  ('Tracy Flores', 491),
#  ('Tyler Tucker', 583),
#  ('Sharon Lewis', 436),
#  ('David Jones', 371),
#  ('Kendra Barton', 406),
#  ('Gail Patrick', 192),
#  ('Kim Hodge', 999),
#  ('Lori Martinez', 124),
#  ('Joseph Doyle', 492),
#  ('Jodi Reynolds', 241),
#  ('Sara Bell', 291),
#  ('Derek Russo', 871),
#  ('Paul Gamble', 493),
#  ('Christopher Hernandez', 199),
#  ('Joshua Hogan', 751),
#  ('Tyler Yang', 765),
#  ('James Roberts', 76),
#  ('Joshua Frye', 53),
#  ('Elizabeth Mendez', 819),
#  ('Joseph Holland', 260),
#  ('Tina Patterson', 250),
#  ('Ashley Williams', 770),
#  ('Lisa Clark', 573),
#  ('Michael Thompson', 611),
#  ('Warren Sanders', 327),
#  ('Julia Andrews', 224),
#  ('Mark Adams', 935),
#  ('Michael Wilson', 38),
#  ('Bruce Porter', 997),
#  ('Sarah Harrison', 271),
#  ('Derek Guzman', 165),
#  ('Olivia Wilson', 947),
#  ('Sarah Greer', 951),
#  ('William Dawson', 471),
#  ('Mary Lewis', 323),
#  ('Sarah Greer', 124),
#  ('Aaron Walker', 430),
#  ('Angela Smith', 571),
#  ('Stephen Hunt', 68),
#  ('Elizabeth Jones', 360),
#  ('Linda Frost', 285),
#  ('Nicholas Perez', 395),
#  ('Mary Bishop', 735),
#  ('Jonathan Lopez', 678),
#  ('Andrew Santos', 22),
#  ('Joshua Callahan', 903),
#  ('Jesse Bryant', 100),
#  ('Linda Wilcox', 682),
#  ('Bianca Carter', 40),
#  ('Mrs. Anita Delgado', 534),
#  ('Adam Caldwell', 18),
#  ('Robert Torres', 58),
#  ('William Wheeler', 3),
#  ('William Dawson', 771),
#  ('Mr. Ryan Thompson', 122),
#  ('Elizabeth Sharp', 879),
#  ('Penny Evans', 91),
#  ('Dr. John Martinez', 679),
#  ('Joshua Baker', 142),
#  ('Travis Lee', 906),
#  ('Kathy Holmes', 881),
#  ('Jordan Moreno', 60),
#  ('Steven Mcdonald', 486),
#  ('Mr. Bradley Garcia', 830),
#  ('Amy Carter', 532),
#  ('Kimberly Carr', 711),
#  ('Matthew White', 864),
#  ('Lisa Richard', 96),
#  ('Matthew Rios', 532),
#  ('Larry Walker', 893),
#  ('Alexis Ward', 957),
#  ('Michelle Wilson', 607),
#  ('Tammy Sanchez', 156),
#  ('Amy Walker', 812),
#  ('Gerald Mcdonald', 888),
#  ('Tammy Garcia', 743),
#  ('Jacob Jimenez', 911),
#  ('Stephanie Harris', 791),
#  ('Louis Brown', 879),
#  ('Melinda Cox', 24),
#  ('Taylor Flores', 176),
#  ('Cindy Lambert', 912),
#  ('James Bowen', 664),
#  ('Sandra Cunningham', 659),
#  ('Debbie Bond', 970),
#  ('Jason Adams', 44),
#  ('Amy Green', 362),
#  ('Michael Gibson', 455),
#  ('Anthony Wood', 187),
#  ('Patrick Clayton III', 699),
#  ('Christopher Taylor', 957),
#  ('Amanda Sellers', 296),
#  ('Jacob Jimenez', 251),
#  ('Stephanie Lopez', 501),
#  ('Thomas Kirk', 291),
#  ('Jennifer Burke', 1),
#  ('Jack Owens', 343),
#  ('Misty Brown', 875),
#  ('Travis Johnson', 732),
#  ('Rebecca Smith', 16),
#  ('Michelle Bentley', 720),
#  ('Mark Adams', 483),
#  ('April Lopez', 423),
#  ('Heather Hernandez', 15),
#  ('Michael Jones', 212),
#  ('Jerry Green', 521),
#  ('Tina Ruiz', 278),
#  ('Kimberly Sims', 148),
#  ('Christine Turner', 270),
#  ('Gabriel Parks', 44),
#  ('Larry Walker', 740),
#  ('Jesse Johnson', 294),
#  ('Michele Jackson', 690),
#  ('Joseph Doyle', 503),
#  ('Kelly Martinez', 99),
#  ('Andrew Moore', 798),
#  ('Mallory Howard', 723),
#  ('Dr. Megan Walker', 725),
#  ('Heather Carlson', 519),
#  ('Mrs. Jenny Lewis', 238),
#  ('Theresa Chambers', 783),
#  ('Julia Craig', 344),
#  ('Melissa Sims', 659),
#  ('Elizabeth Park', 510),
#  ('Mr. Thomas Robinson MD', 714),
#  ('Kendra Morgan', 635),
#  ('Nicole Edwards', 509),
#  ('Jeffery Matthews', 806),
#  ('Mr. Steven Rogers MD', 642),
#  ('Shawn White', 907),
#  ('Jill Barnes', 242),
#  ('Jill Faulkner', 624),
#  ('Pamela Jones', 514),
#  ('Kelly Burch', 387),
#  ('Lucas Alexander', 181),
#  ('Jessica Phillips', 766),
#  ('Adam Caldwell', 187),
#  ('James Li', 300),
#  ('Amy Rhodes', 732),
#  ('Jessica Nguyen', 21),
#  ('Daniel Dawson', 189),
#  ('Stephanie Bryant', 41),
#  ('Mario Johnston', 280),
#  ('Barbara Rivera', 413),
#  ('Joel Anthony II', 62),
#  ('Jordan Simon', 565),
#  ('Loretta Evans', 177),
#  ('Mary Burke', 315),
#  ('Dr. David Gallagher PhD', 729),
#  ('Holly Harris', 757),
#  ('Jenna White', 952),
#  ('Todd Cooper', 883),
#  ('Susan Phillips', 120),
#  ('Laura Miller', 449),
#  ('Lindsay Francis', 431),
#  ('Andrew Brown', 329),
#  ('William Rocha', 238),
#  ('Tracy Flores', 781),
#  ('Tony Roberts', 395),
#  ('Nicole Miller', 473),
#  ('Stephanie West', 883),
#  ('Jordan West', 929),
#  ('Patricia Johnson', 880),
#  ('Nathan Smith', 797),
#  ('Michael Thompson', 953),
#  ('Morgan Arias', 126),
#  ('Hannah Norris', 2),
#  ('Shawn Simon', 882),
#  ('Traci Williams', 238),
#  ('Amanda Flowers', 966),
#  ('Sherri Beck', 84),
#  ('Debbie Bond', 124),
#  ('Jennifer White', 396),
#  ('Lindsay Reed', 54),
#  ('Denise Knight', 953),
#  ('Michele Grant', 493),
#  ('Andrew Becker', 322),
#  ('Brendan Russell', 357),
#  ('Warren Sanders', 829),
#  ('Dwayne Rojas', 134),
#  ('William Hardy', 769),
#  ('Erin Davis', 792),
#  ('Christina French', 52),
#  ('Victoria Moses', 21),
#  ('Patricia Johnson', 778),
#  ('Christopher Woods', 53),
#  ('Loretta Evans', 288),
#  ('Elizabeth Sharp', 699),
#  ('Nancy Shaw', 382),
#  ('Amanda Parks', 500),
#  ('Seth Simpson', 799),
#  ('Curtis Mccall', 558),
#  ('Lindsay Daniels', 1),
#  ('Stephanie Lopez', 594),
#  ('Larry Walker', 241),
#  ('Anthony Riley', 441),
#  ('Vanessa Johnson', 508),
#  ('Matthew Miranda', 559),
#  ('Frank Watson', 690),
#  ('Lawrence Rodriguez', 426),
#  ('Steven Mcdonald', 18),
#  ('Joshua Stevenson', 675),
#  ('Alex Sutton', 10),
#  ('Michael Lopez', 157),
#  ('Melissa Williams', 923),
#  ('Gregory Gregory', 243),
#  ('Sara Wheeler', 313),
#  ('Karina Reese', 226),
#  ('Jacob Deleon', 610),
#  ('Dr. David Gallagher PhD', 289),
#  ('William Wheeler', 329),
#  ('Patrick Norris', 748),
#  ('April Walker', 425),
#  ('Rebecca Smith', 530),
#  ('Sandra Johnson', 192),
#  ('Amber Anderson', 308),
#  ('Reginald Payne', 860),
#  ('Vicki Jensen', 797),
#  ('Joshua Hogan', 794),
#  ('Jesse Bryant', 609),
#  ('Angela Palmer', 68),
#  ('Kayla Adams', 327),
#  ('Sharon Russell', 607),
#  ('Autumn Horton', 562),
#  ('Joseph Mendez', 131),
#  ('Bryce Reeves', 272),
#  ('Stephanie Gonzalez', 939),
#  ('James Ramos', 592),
#  ('Lindsay Reed', 696),
#  ('Vanessa Johnson', 178),
#  ('Kimberly Daniels', 525),
#  ('Shannon Daniel', 706),
#  ('Mitchell Jones', 954),
#  ('David Salazar', 914),
#  ('Christopher Russell', 41),
#  ('Shirley Lewis', 321),
#  ('Eric Walls', 295),
#  ('Jerry Green', 18),
#  ('Tamara Poole', 219),
#  ('Holly Mcdonald', 387),
#  ('Robert Howard', 425),
#  ('Mary Rice', 785),
#  ('Michelle Bentley', 820),
#  ('Robert Craig', 237),
#  ('David Ford', 996),
#  ('Denise Knight', 221),
#  ('Angela Pace', 371),
#  ('Mario Miller', 573),
#  ('Amber Page', 831),
#  ('David Ford', 451),
#  ('Julie Ryan', 192),
#  ('Jeffrey Calhoun', 984),
#  ('Dr. John Martinez', 73),
#  ('Karen Johnson', 586),
#  ('Daniel King', 315),
#  ('Amber Anderson', 370),
#  ('Joshua Hampton', 803),
#  ('Sherri Beck', 16),
#  ('Bonnie Carroll', 824),
#  ('Julie Love', 542),
#  ('Andrew Snyder', 15),
#  ('Tina Patterson', 863),
#  ('Juan Duarte', 635),
#  ('Dr. Jose Friedman', 323),
#  ('Felicia Howard', 296),
#  ('Sandra Mccall DDS', 199),
#  ('Tammy Sanchez', 777),
#  ('Mary Nelson', 854),
#  ('Tamara Poole', 635),
#  ('Heather Guerrero', 961),
#  ('Reginald Payne', 413),
#  ('Elizabeth Arellano', 173),
#  ('Kristy Hernandez', 160),
#  ('Melissa Farley', 137),
#  ('Tyler Murphy', 929),
#  ('Linda Green', 211),
#  ('Eduardo Scott', 439),
#  ('Julie Henderson', 411),
#  ('Brandon Edwards', 550),
#  ('Christine Young', 386),
#  ('Kristin Lin', 588),
#  ('Angela Walker', 433),
#  ('Danielle Price', 586),
#  ('Kathryn Miller', 569),
#  ('Michael Gilbert', 342),
#  ('Mrs. Brittany Wade DVM', 956),
#  ('Linda Green', 646),
#  ('Dr. Kevin Nichols DDS', 132),
#  ('Russell Ruiz', 640),
#  ('Kim Hodge', 337),
#  ('Elizabeth Thomas', 162),
#  ('John Christian', 391),
#  ('Ashley Moran', 401),
#  ('Daniel Howard', 387),
#  ('Angela Trujillo', 863),
#  ('Marc Gutierrez', 476),
#  ('Michael Carlson', 266),
#  ('Troy Bell', 152),
#  ('Richard Davies', 949),
#  ('Brendan Wells', 821),
#  ('Amy Green', 933),
#  ('Elizabeth Hayes', 872),
#  ('Kelly Burch', 168),
#  ('Juan Blackburn', 248),
#  ('Eric Garcia', 837),
#  ('Dean Davis', 398),
#  ('Melanie Scott', 691),
#  ('Jessica Garner', 400),
#  ('Julie Woodard', 690),
#  ('Teresa Lee', 59),
#  ('Deborah Clements', 840),
#  ('Kenneth Mclean', 694),
#  ('Frank Ellis', 464),
#  ('Tiffany Weaver', 748),
#  ('Dr. Kevin Nichols DDS', 116),
#  ('Jamie Martinez', 554),
#  ('Jeremiah Clayton', 456),
#  ('Christina Ross', 688),
#  ('Stephen Hicks', 855),
#  ('Thomas Carroll', 421),
#  ('Lindsay Francis', 123),
#  ('Melissa Sims', 641),
#  ('Lindsay Daniels', 827),
#  ('Christopher Russell', 356),
#  ('Taylor Flores', 774),
#  ('Kimberly Thomas', 520),
#  ('Lori Wood', 589),
#  ('Eric Garcia', 457),
#  ('Arthur Richardson', 798),
#  ('Sean Johnson', 405),
#  ('Timothy Blackburn', 346),
#  ('Ryan Clark', 611),
#  ('Adam Everett', 2),
#  ('Elizabeth Park', 903),
#  ('Shannon Webb', 669),
#  ('Wendy Williams', 836),
#  ('Adam Williams', 325),
#  ('Julie Henderson', 339),
#  ('Arthur Richardson', 536),
#  ('Eric Ward', 765),
#  ('Mary Perry', 704),
#  ('Alice Travis', 419)]

# %% [markdown]
# ### Challenge: Write a CSV file
#
# **This challenge isn't for extra marks, it's an opportunity for you to engage in some self guided discovery, only if you feel like it, and only if you have time.**
#
# If you want to challenge yourself, alter the report so that it conforms with the `.csv` file type. There are a number of ways to do this, you can use the `Pandas` module, the `csv` module, or manually.
